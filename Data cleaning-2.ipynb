# %% [markdown]
# # How to fill missing values - using drop

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

print(np.__version__)
# Out:
# 2.2.4

# %%
dataset = pd.read_csv("california_cities.csv")

# %%
dataset.head(4)
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
#
#    area_total_km2  area_land_km2  area_water_km2  area_water_percent
# 0         145.107        145.062           0.046                0.03
# 1          20.260         20.184           0.076                0.37
# ...

# %%
dataset.shape
# Out:
# (482, 14)

# %%
dataset.shape
# Out:
# (464, 13)

# %%
((482-464)/482)*100                             # percentage of deleted data which was missing
# Out:
# 3.7344398340248963

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# city                  0
# latd                  0
# longd                 0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         0
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(columns=["elevation_m"], inplace=True, errors='ignore')      # delets nthe columns named containing more missing values

# %%
dataset.dropna(inplace=True)         # it removes all the rows containing missing data
