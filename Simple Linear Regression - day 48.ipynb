# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('package(in lpa)')
# Out:
# Text(0, 0.5, 'package(in lpa)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state = 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
#      cgpa
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77
# ..    ...
# 43   7.66
# 22   6.14
# 72   7.78
# 15   7.25
# 168  8.65
#
# [160 rows x 1 columns]

# %%
y_train
# Out:
# 137    3.13
# 163    3.91
# 111    2.25
# 123    2.30
# 109    4.06
#        ...
# 43     2.76
# 22     2.30
# 72     3.62
# 15     3.23
# 168    3.52
# Name: package, Length: 160, dtype: float64

# %%
lr.predict(X_train.iloc[2].values.reshape(1,1))
# Out:
# C:\Users\zisha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.12798777])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('package(in lpa)')
# Out:
# Text(0, 0.5, 'package(in lpa)')

# %%
m = lr.coef_

# %%
b = lr.intercept_

# %%
# y = mx + b

# m*cgpa + b

m*8.58 + b
# Out:
# array([3.89111601])

# %%
m*9.5 + b
# Out:
# array([4.40443183])

# %%
m*100 + b
# Out:
# array([54.89908542])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred = lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))     # ye bta rha ki kitna lpa ka hmara m odel glti kr rha
# Out:
# MAE 0.2884710931878175

# %%
print("MSE",mean_squared_error(y_test,y_pred))    # ye lpa*2 me h
# Out:
# MSE 0.12129235313495527

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 0.34827051717731616

# %%
print("MSE",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# MSE 0.780730147510384

# %%
# Adjusted R2 score
X_test.shape
# Out:
# (40, 1)

# %%
# calculating Adjusted R2 score
1 - ((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7749598882343415
