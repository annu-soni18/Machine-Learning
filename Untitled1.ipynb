# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
plt.scatter(df['cgpa'], df['iq'],c=df['placement'])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,2:]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
#     placement
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# ..        ...
# 95          0
# 96          0
# 97          1
# 98          1
# 99          1
#
# [100 rows x 1 columns]

# %%
y.shape
# Out:
# (100, 1)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 20   6.6  120.0
# 94   4.7   52.0
# 31   3.9  109.0
# 43   6.8  141.0
# 37   8.1  149.0
# ..   ...    ...
# 35   6.8   90.0
# 1    5.9  106.0
# 4    5.8  142.0
# 44   7.5   61.0
# 72   7.3  116.0
#
# [90 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)       

# data ko 0 and 1 k bich covert or transform kr rhe

# %%
x_train
# Out:
# array([[ 0.4984073 , -0.05549149],
#        [-1.17272305, -1.76206385],
#        [-1.87635688, -0.33155466],
#        [ 0.67431575,  0.47153821],
#        [ 1.81772073,  0.67231143],
#        [-0.90886036, -1.48600067],
#        [-0.73295191,  0.24566834],
#        [ 1.37794958,  0.14528173],
#        [ 0.05863615, -0.48213458],
#        [-0.55704345,  0.3209583 ],
#        [-0.20522653,  1.09895452],
#        [ 1.28999536,  0.19547504],
#        [-0.29318076,  0.44644156],
#        [ 0.93817844,  0.72250474],
#        [-1.43658574,  0.67231143],
#        [-0.73295191, -0.80839106],
#        [-0.29318076,  0.52173152],
#        [-0.29318076,  0.24566834],
#        [-2.40408225,  1.52559761],
#        [-1.08476882,  1.17424448],
#        [-2.2281738 ,  2.78043023],
#        [ 0.76226998,  0.42134491],
#        [-0.73295191,  0.97347126],
#        [-0.02931808,  0.04489512],
#        [ 0.85022421,  0.42134491],
#        [-0.90886036, -0.10568479],
#        [ 0.4984073 ,  0.39624826],
#        [ 0.58636153,  1.50050096],
#        [-0.82090614,  0.14528173],
#        [ 0.85022421,  1.32482439],
#        [ 0.41045307,  0.94837461],
#        [ 0.85022421,  1.92714405],
#        [ 0.23454461,  0.12018508],
#        [ 0.67431575,  0.01979847],
#        [ 1.55385804, -0.2060714 ],
#        [-0.64499768, -0.2060714 ],
#        [ 1.1140869 , -0.90877767],
#        [-1.17272305, -0.03039483],
#        [ 0.93817844, -1.86245046],
#        [ 1.81772073,  1.09895452],
#        [ 0.76226998, -0.65781114],
#        [-1.78840265, -1.18484084],
#        [-0.02931808, -1.41071071],
#        [ 0.32249884,  0.47153821],
#        [-0.02931808,  0.67231143],
#        [ 0.23454461, -0.48213458],
#        [-0.02931808, -0.50723123],
#        [ 0.32249884, -0.1558781 ],
#        [ 0.05863615,  0.847988  ],
#        [ 0.67431575, -0.25626471],
#        [ 0.05863615, -1.43580737],
#        [ 0.41045307, -2.13851363],
#        [-0.73295191, -0.30645801],
#        [-0.29318076,  1.17424448],
#        [ 0.14659038, -0.23116805],
#        [ 1.1140869 ,  0.3711516 ],
#        [-1.43658574, -2.01303037],
#        [-0.99681459, -1.53619397],
#        [ 0.85022421, -1.46090402],
#        [-0.82090614,  1.34992104],
#        [ 0.85022421, -0.25626471],
#        [ 1.99362919,  1.14914783],
#        [-0.99681459,  0.82289135],
#        [-0.99681459,  0.29586165],
#        [ 2.16953764, -0.05549149],
#        [-0.99681459,  1.85185409],
#        [-0.90886036, -0.7832944 ],
#        [-0.99681459,  0.72250474],
#        [-0.55704345, -0.2060714 ],
#        [ 1.1140869 , -1.81225715],
#        [-0.99681459, -0.05549149],
#        [-0.55704345, -0.38174797],
#        [-0.02931808, -1.93774041],
#        [-1.52453997,  1.9522407 ],
#        [ 1.37794958, -0.83348771],
#        [ 0.05863615,  0.24566834],
#        [-0.55704345,  0.42134491],
#        [ 1.28999536,  0.8981813 ],
#        [-0.82090614, -1.41071071],
#        [ 1.7297665 , -1.08445423],
#        [-1.08476882,  0.47153821],
#        [ 0.41045307,  0.19547504],
#        [ 0.05863615, -1.03426093],
#        [-1.26067728,  0.59702147],
#        [ 0.41045307, -0.80839106],
#        [ 0.67431575, -0.80839106],
#        [-0.11727231, -0.40684462],
#        [-0.20522653,  0.49663486],
#        [ 1.28999536, -1.53619397],
#        [ 1.1140869 , -0.1558781 ]])

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[  5.2, 224. ],
#        [  6.7, 154. ],
#        [  7.4, 132. ],
#        [  4. , 100. ],
#        [  6.3, 128. ],
#        [  6.9, 138. ],
#        [  4.8, 163. ],
#        [  5.3, 121. ],
#        [  4.7,  87. ],
#        [  4.8, 112. ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)       # using Logistic Regression (Model Training alorithm)
# Out:
# C:\Users\zisha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
#     placement
# 16          0
# 74          1
# 3           1
# 18          0
# 63          1
# 11          1
# 34          0
# 2           0
# 23          0
# 59          0

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\zisha\anaconda3\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\zisha\anaconda3\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\zisha\anaconda3\lib\site-packages (from mlxtend) (2.1.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\zisha\anaconda3\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\zisha\anaconda3\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\zisha\appdata\roaming\python\python312\site-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\zisha\anaconda3\lib\site-packages (from mlxtend) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zisha\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\zisha\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zisha\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\zisha\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\zisha\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\zisha\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\zisha\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zisha\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zisha\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zisha\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\zisha\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\zisha\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values.ravel(),clf=clf,legend = 2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf, open('model.pkl','wb'))
