# %%
pip install Matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Bsic graph

# %%
# for plottin g simple graph
x = [5, 10, 15, 20, 25]
y = [6, 12, 18, 24, 30]

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,color = 'yellow')        # color

# %%
plt.plot(x,y,color = 'yellow', marker='*')
plt.show()

# %%
plt.plot(x,y,color = 'yellow', marker='*', markeredgecolor='blue', markersize=10)
plt.show()

# %%
plt.plot(x,y,color = 'm', marker='*',  linestyle='--', markeredgecolor='blue', markersize=10)
plt.show()

# %%
plt.plot(x,y,'r*--')                   # color marker linestyle - short form

# %%
plt.plot(x,y,'r*--')                                      #() iske andr jo likha h wo us sub module ka Attribute h
plt.title('Heading1')                                #For heading of the graph
# Out:
# Text(0.5, 1.0, 'Heading1')

# %%
plt.plot(x,y,'r*--')
plt.title('First Graph',fontdict={'fontname': 'comic Sans MS', 'fontsize':20})
# Out:
# Text(0.5, 1.0, 'First Graph')

# %%
plt.plot(x,y,'r*--')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
plt.plot(x,y,'b*-')
plt.legend(['single element'])
plt.show()

# %%
plt.plot(x,y,'b*--')
plt.savefig('firstgraph.png',dpi=200)

# %%
# Line Graph
import pandas as pd

# %%
mob = pd.read_csv('soni.csv')

# %%
mob
# Out:
#    Unnamed: 0  year  india  china  america  japan
# 0           0  2000   5000    400      800    300
# 1           1  2001   6000   5000     9000   4000
# 2           2  2002   7000   6000    15000   8000
# 3           3  2003   8000   7000    18000   9000
# 4           4  2004   9000   8000    20000  15000

# %%
plt.plot(mob.year, mob.india, 'b.-', label='India')
plt.plot(mob.year, mob.china, 'r.-', label='china')
plt.plot(mob.year, mob.japan, 'g.-', label='japan')
plt.plot(mob.year, mob.america, 'm.-', label='america')

plt.xlabel('year')
plt.ylabel('price')
plt.title('Mobile Price year wise',fontdict={'fontname': 'comic Sans MS', 'fontsize':20} )

plt.legend()
plt.savefig('mobilePrice.png')
plt.plot()
# Out:
# []

# %% [markdown]
# # Histogram

# %%
bunch = [0, 20, 40, 60, 80, 100]
x = [10, 20, 30, 40, 50, 60]

plt.hist(x,bins=bunch,color='m')
plt.xlabel('Bunch')
plt.ylabel('Data')
plt.legend(["ok"])

plt.show()

# %% [markdown]
# # Piechart

# %%
import numpy as np

# %%
y = np.array([25, 30, 35, 40])
name = ["aaaa", "bbbb", "cccc", "dddd"]
plt.pie(y,labels=name)
plt.show()

# %%
# Explode
nameexplode = [0, 0, 0, 0.2]
plt.pie(y,labels=name, explode=nameexplode)
plt.show()

# %%
plt.pie(y,labels=name, explode=nameexplode, shadow= True)
plt.savefig('pie.png', dpi=300)
plt.show()

# %%
 mycolor = ['b', 'red', 'black', 'm']
plt.pie(y,labels=name, explode=nameexplode, shadow= True, colors = mycolor)
plt.legend()
plt.show()

# %%
test = np.random.normal(200, 50, 400)
plt.boxplot(test)
plt.show()

# %%
test1 = np.random.normal(200, 50, 400)
test2 = np.random.normal(100, 50, 300)
test3 = np.random.normal(150, 100, 300)
test4 = np.random.normal(250, 75, 400)

data = [test1, test2, test3, test4]
plt.boxplot(data)
plt.show()

# %% [markdown]
# # Scatter plot

# %%
x = [1, 2, 3, 4, 5]
y = [5, 6, 7, 8, 9]

plt.scatter(x,y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [5, 6, 7, 8, 9]

a = [7, 4, 3, 8, 2]
b = [9, 5, 3, 6, 1]


plt.scatter(x,y)
plt.scatter(a,b)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [5, 6, 7, 8, 9]

a = [7, 4, 3, 8, 2]
b = [9, 5, 3, 6, 1]

t= [3,5,6,7,8]
h= [2,4,5,6,7]


plt.scatter(x,y)
plt.scatter(a,b)
plt.scatter(t,h)
plt.show()
