# %%
import numpy as np
import pandas as pd

# %%
dict = {
    "name" : ['soni', 'sapna', 'skill','shubh'],
    "marks" :[87, 45, 23, 90],
    "city" :['rampur', 'kolkata', 'barauli', 'antartika']
}

# %%
df=pd.DataFrame(dict)

# %%
df
# Out:
#     name  marks       city
# 0   soni     87     rampur
# 1  sapna     45    kolkata
# 2  skill     23    barauli
# 3  shubh     90  antartika

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv', index=False)

# %%
df.head(2)
# Out:
#     name  marks     city
# 0   soni     87   rampur
# 1  sapna     45  kolkata

# %%
df.tail(3)
# Out:
#     name  marks       city
# 1  sapna     45    kolkata
# 2  skill     23    barauli
# 3  shubh     90  antartika

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   61.250000
# std    32.745229
# min    23.000000
# 25%    39.500000
# 50%    66.000000
# 75%    87.750000
# max    90.000000

# %%
df.index = ['first', 'second', 'third', 'fourth']

# %%
df
# Out:
#          name  marks       city
# first    soni     87     rampur
# second  sapna     45    kolkata
# third   skill     23    barauli
# fourth  shubh     90  antartika

# %%
# series and Dataframe

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.512900
# 1     0.589344
# 2     0.929423
# 3     0.684991
# 4     0.788124
# 5     0.820221
# 6     0.677613
# 7     0.945796
# 8     0.764576
# 9     0.080312
# 10    0.820805
# 11    0.636814
# 12    0.226714
# 13    0.753365
# 14    0.007104
# 15    0.515190
# 16    0.122839
# 17    0.635500
# 18    0.664846
# 19    0.688144
# 20    0.326442
# 21    0.100992
# 22    0.409659
# 23    0.988977
# 24    0.557406
# 25    0.431209
# 26    0.305461
# 27    0.242707
# 28    0.851531
# 29    0.857487
# 30    0.134227
# 31    0.338935
# 32    0.641316
# 33    0.127968
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf  = pd.DataFrame(np.random.rand(221,5), index = np.arange(221))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.553493  0.969262  0.367898  0.538308  0.389987
# 1    0.051481  0.026628  0.625347  0.205217  0.035287
# 2    0.812787  0.687916  0.371589  0.667374  0.960579
# 3    0.721710  0.676099  0.293961  0.040063  0.904107
# 4    0.738276  0.018562  0.473428  0.456314  0.078340
# ..        ...       ...       ...       ...       ...
# 216  0.750043  0.612340  0.917628  0.272993  0.801011
# 217  0.908143  0.471073  0.815198  0.871070  0.605915
# 218  0.448563  0.568244  0.247561  0.345276  0.261476
# 219  0.084700  0.370118  0.674171  0.295923  0.117947
# 220  0.419634  0.221161  0.626660  0.641140  0.575044
#
# [221 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  221.000000  221.000000  221.000000  221.000000  221.000000
# mean     0.521379    0.504052    0.486217    0.483886    0.475335
# std      0.292821    0.290195    0.284315    0.282174    0.281766
# min      0.002981    0.000407    0.000501    0.000609    0.006912
# 25%      0.258218    0.236968    0.244009    0.260695    0.252062
# 50%      0.541812    0.514516    0.485250    0.456314    0.464857
# 75%      0.761401    0.746891    0.740886    0.742815    0.729291
# max      0.999524    0.991633    0.993926    0.999324    0.998367

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.553493  0.969262  0.367898  0.538308  0.389987
# 1  0.051481  0.026628  0.625347  0.205217  0.035287
# 2  0.812787  0.687916  0.371589  0.667374  0.960579
# 3  0.721710  0.676099  0.293961  0.040063  0.904107
# 4  0.738276  0.018562  0.473428  0.456314  0.078340

# %%
newdf[0][0] = "soni"
# Out:
# C:\Users\zisha\AppData\Local\Temp\ipykernel_8124\3001414116.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf[0][0] = "soni"
# ...

# %%
newdf
# Out:
#             0         1         2         3         4
# 0
#             0         1         2         3         4
# 220  0.419634  0.221161  0.626660  0.641140  0.575044
# 219    0.0847  0.370118  0.674171  0.295923  0.117947
# 218  0.448563  0.568244  0.247561  0.345276  0.261476
# 217  0.908143  0.471073  0.815198  0.871070  0.605915
# 216  0.750043  0.612340  0.917628  0.272993  0.801011
# ..        ...       ...       ...       ...       ...
# 4    0.738276  0.018562  0.473428  0.456314  0.078340
# 3     0.72171  0.676099  0.293961  0.040063  0.904107
# 2    0.812787  0.687916  0.371589  0.667374  0.960579
# 1    0.051481  0.026628  0.625347  0.205217  0.035287
# 0        soni  0.969262  0.367898  0.538308  0.389987
#
# [221 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0      soni  0.969262  0.367898  0.538308  0.389987
# 1  0.051481  0.026628  0.625347  0.205217  0.035287
# 2  0.812787  0.687916  0.371589  0.667374  0.960579
# 3   0.72171  0.676099  0.293961  0.040063  0.904107
# 4  0.738276  0.018562  0.473428  0.456314  0.078340

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
newdf.loc[0,0] = 55    # set new value

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0        55  0.969262  0.367898  0.538308  0.389987
# 1  0.051481  0.026628  0.625347  0.205217  0.035287

# %%
newdf.columns = list("ABCDE")

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0        55  0.969262  0.367898  0.538308  0.389987
# 1  0.051481  0.026628  0.625347  0.205217  0.035287

# %%
newdf.loc[0,0] = 8888888

# %%
newdf
# Out:
#             A         B         C         D         E          0
# 0          55  0.969262  0.367898  0.538308  0.389987  8888888.0
# 1    0.051481  0.026628  0.625347  0.205217  0.035287        NaN
# 2    0.812787  0.687916  0.371589  0.667374  0.960579        NaN
# 3     0.72171  0.676099  0.293961  0.040063  0.904107        NaN
# 4    0.738276  0.018562  0.473428  0.456314  0.078340        NaN
# ..        ...       ...       ...       ...       ...        ...
# 216  0.750043  0.612340  0.917628  0.272993  0.801011        NaN
# 217  0.908143  0.471073  0.815198  0.871070  0.605915        NaN
# 218  0.448563  0.568244  0.247561  0.345276  0.261476        NaN
# 219    0.0847  0.370118  0.674171  0.295923  0.117947        NaN
# 220  0.419634  0.221161  0.626660  0.641140  0.575044        NaN
#
# [221 rows x 6 columns]

# %%
newdf=newdf.drop(0, axis=1)

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0        55  0.969262  0.367898  0.538308  0.389987
# 1  0.051481  0.026628  0.625347  0.205217  0.035287
# 2  0.812787  0.687916  0.371589  0.667374  0.960579
# 3   0.72171  0.676099  0.293961  0.040063  0.904107
# 4  0.738276  0.018562  0.473428  0.456314  0.078340

# %%
newdf.loc[[1,2], ['C', 'D']]
# Out:
#           C         D
# 1  0.625347  0.205217
# 2  0.371589  0.667374

# %%
newdf.loc[:,['A', 'B']]
# Out:
#             A         B
# 0          55  0.969262
# 1    0.051481  0.026628
# 2    0.812787  0.687916
# 3     0.72171  0.676099
# 4    0.738276  0.018562
# ..        ...       ...
# 216  0.750043  0.612340
# 217  0.908143  0.471073
# 218  0.448563  0.568244
# 219    0.0847  0.370118
# 220  0.419634  0.221161
#
# [221 rows x 2 columns]

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E
# 1  0.051481  0.026628  0.625347  0.205217  0.035287
# 2  0.812787  0.687916  0.371589  0.667374  0.960579

# %%
newdf.loc[(newdf['A']<0.3)]
# Out:
#             A         B         C         D         E
# 1    0.051481  0.026628  0.625347  0.205217  0.035287
# 5    0.206414  0.316735  0.000501  0.787210  0.661822
# 16   0.250439  0.891061  0.296321  0.264082  0.028003
# 23   0.164733  0.233732  0.486565  0.421668  0.230080
# 36   0.128424  0.574709  0.610476  0.247907  0.369976
# ..        ...       ...       ...       ...       ...
# 211  0.237285  0.840817  0.258030  0.751338  0.299798
# 212  0.195536  0.581626  0.691286  0.333341  0.076569
# 213  0.198424  0.641278  0.276449  0.075333  0.466556
# 214  0.146236  0.360792  0.640633  0.148222  0.802204
# 219    0.0847  0.370118  0.674171  0.295923  0.117947
#
# [66 rows x 5 columns]

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0        55  0.969262  0.367898  0.538308  0.389987
# 1  0.051481  0.026628  0.625347  0.205217  0.035287

# %%
newdf.iloc[0,4]
# Out:
# np.float64(0.38998721491110877)

# %%
newdf.iloc[[0,5], [1,2]]
# Out:
#           B         C
# 0  0.969262  0.367898
# 5  0.316735  0.000501

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.051481  0.026628  0.625347  0.205217  0.035287
# 2    0.812787  0.687916  0.371589  0.667374  0.960579
# 3     0.72171  0.676099  0.293961  0.040063  0.904107
# 4    0.738276  0.018562  0.473428  0.456314  0.078340
# 5    0.206414  0.316735  0.000501  0.787210  0.661822
# ..        ...       ...       ...       ...       ...
# 216  0.750043  0.612340  0.917628  0.272993  0.801011
# 217  0.908143  0.471073  0.815198  0.871070  0.605915
# 218  0.448563  0.568244  0.247561  0.345276  0.261476
# 219    0.0847  0.370118  0.674171  0.295923  0.117947
# 220  0.419634  0.221161  0.626660  0.641140  0.575044
#
# [220 rows x 5 columns]

# %%
newdf.drop(['A','D'], axis=1, inplace=True)

# %%
newdf
# Out:
#             B         C         E
# 0    0.969262  0.367898  0.389987
# 1    0.026628  0.625347  0.035287
# 2    0.687916  0.371589  0.960579
# 3    0.676099  0.293961  0.904107
# 4    0.018562  0.473428  0.078340
# ..        ...       ...       ...
# 216  0.612340  0.917628  0.801011
# 217  0.471073  0.815198  0.605915
# 218  0.568244  0.247561  0.261476
# 219  0.370118  0.674171  0.117947
# 220  0.221161  0.626660  0.575044
#
# [221 rows x 3 columns]

# %%
newdf.head()
# Out:
#           B         C         E
# 0  0.969262  0.367898  0.389987
# 1  0.026628  0.625347  0.035287
# 2  0.687916  0.371589  0.960579
# 3  0.676099  0.293961  0.904107
# 4  0.018562  0.473428  0.078340

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf.head(3)
# Out:
#           B         C         E
# 0  0.969262  0.367898  0.389987
# 1  0.026628  0.625347  0.035287
# 2  0.687916  0.371589  0.960579

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 216    False
# 217    False
# 218    False
# 219    False
# 220    False
# Name: B, Length: 221, dtype: bool

# %%
newdf['B'] = None

# %%
newdf
# Out:
#         B         C         E
# 0    None  0.367898  0.389987
# 1    None  0.625347  0.035287
# 2    None  0.371589  0.960579
# 3    None  0.293961  0.904107
# 4    None  0.473428  0.078340
# ..    ...       ...       ...
# 216  None  0.917628  0.801011
# 217  None  0.815198  0.605915
# 218  None  0.247561  0.261476
# 219  None  0.674171  0.117947
# 220  None  0.626660  0.575044
#
# [221 rows x 3 columns]

# %%
dict = {
   "year" : [2000, 2001, 2002, 2003, 2004],
    "india" :[5000, 6000, 7000, 8000, 9000],
    "china" :[400, 5000, 6000, 7000, 8000],
    "america" : [800, 9000, 15000, 18000, 20000],
    "japan" : [300, 4000, 8000, 9000, 15000]

}

# %%
an=pd.DataFrame(dict)

# %%
an
# Out:
#    year  india  china  america  japan
# 0  2000   5000    400      800    300
# 1  2001   6000   5000     9000   4000
# 2  2002   7000   6000    15000   8000
# 3  2003   8000   7000    18000   9000
# 4  2004   9000   8000    20000  15000

# %%
an.to_csv('soni.csv')
