# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\zisha\anaconda3\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\zisha\anaconda3\lib\site-packages (from plotly) (2.2.0)
# Requirement already satisfied: packaging in c:\users\zisha\appdata\roaming\python\python312\site-packages (from plotly) (24.2)

# %%
x,y = make_regression(n_samples  = 100, n_features = 2, n_informative = 2, n_targets = 1, noise = 50)
# here we are  creating a regrssion t

# %%
df = pd.DataFrame({'feature1':X[:,0], 'feature2':
